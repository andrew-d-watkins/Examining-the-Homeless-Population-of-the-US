# %% [markdown]
# # Examining the Homeless Population of the United States
# By Andrew Watkins

# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# In this section we will do some basic statistics on our dataset. We will check distributions and correraltions between variables.

# %%
#Data Wrangling from previous section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Name the files to use
file_hic_state = 'data/2007-2017-HIC-Counts-by-State.xlsx'
file_pit_state = 'data/2007-2017-PIT-Counts-by-State.xlsx'

# Load spreadsheet
hic_state = pd.ExcelFile(file_hic_state)
pit_state = pd.ExcelFile(file_pit_state)

#HIC
df_hic = pd.DataFrame()

#concat the rest of the sheets to the original df
for sheet in range(2007, 2018): 
    excel_sheet = hic_state.parse(str(sheet), header=1)
    excel_sheet['year'] = str(sheet)
    excel_sheet.set_index(['year','State'], inplace=True)
    df_hic = pd.concat([df_hic, excel_sheet], axis=0, ignore_index=False, sort=True)
    
#Columns were named differenlty before 2014 so we will use all the named variations and then combine them.
columns_to_use = [ "Total Year-Round Beds (ES)",
                   "Total Year-Round ES Beds",
                   "Total Year-Round Beds (TH)",
                   "Total Year-Round TH Beds",
                   "Total Year-Round Beds (SH)",
                   "Total Year-Round SH Beds",
                   "Total Year-Round Beds (PSH)",
                   "Total Year-Round PSH Beds",
                   "Total Year-Round Beds (RRH)",
                   "Total Year-Round RRH Beds",
                   "Total Year-Round Beds (DEM)",
                   "Total Year-Round Beds (OPH)",
]
df_hic = df_hic[columns_to_use]
df_hic.fillna(0.0, inplace=True)


#Here we combine the coumns that contain the same informaiton but were named differently. 
df_hic['Total Year-Round Beds (ES)'] = df_hic['Total Year-Round Beds (ES)'] + df_hic['Total Year-Round ES Beds']
df_hic['Total Year-Round Beds (TH)'] = df_hic['Total Year-Round Beds (TH)'] + df_hic['Total Year-Round TH Beds']
df_hic['Total Year-Round Beds (SH)'] = df_hic['Total Year-Round Beds (SH)'] + df_hic['Total Year-Round SH Beds']
df_hic['Total Year-Round Beds (PSH)'] = df_hic['Total Year-Round Beds (PSH)'] + df_hic['Total Year-Round PSH Beds']
df_hic['Total Year-Round Beds (RRH)'] = df_hic['Total Year-Round Beds (RRH)'] + df_hic['Total Year-Round RRH Beds']

#We drop the extra columns we no longer need.
cols_to_drop = ['Total Year-Round ES Beds',
                'Total Year-Round TH Beds',
                'Total Year-Round SH Beds',
                'Total Year-Round PSH Beds',
                'Total Year-Round RRH Beds']
df_hic.drop(cols_to_drop, axis=1, inplace=True)

#PIT
#Create a new DF with the rest of the sheets. Which are the homeless population in each state from 2007-2017
df_pit = pd.DataFrame()

#concat the rest of the sheets to the original df
for sheet in range(2007, 2018):
    excel_sheet = pit_state.parse(str(sheet))
    excel_sheet['year'] = str(sheet)
    excel_sheet.set_index(['year','State'], inplace=True)
    #rename the columns
    cols_to_use = []
    for column in excel_sheet.columns:
        if column.__contains__(','):
            cols_to_use.append(column.split(',')[0])
        else:
            cols_to_use.append(column)
    excel_sheet.columns = cols_to_use
    df_pit = pd.concat([df_pit, excel_sheet], axis=0, ignore_index=False, sort=True)
    
#There are only two with the note. So we just drop them directly. 
df_pit.drop(level=1, inplace=True, index='Note: The number of CoCs in 2016 was 402. However, MO-604 merged in 2016 and covers territory in both MO and KS, contributing to the PIT count in both states. ')
df_pit.drop(level=1, inplace=True, index='Note: The number of CoCs in 2017 was 399. However, MO-604 merged in 2016 and covers territory in both MO and KS, contributing to the PIT count in both states. ')

#Grab the 2 columns that we need for now
df_pit = df_pit[['Total Homeless', 'Number of CoCs']]
df_pit.fillna(0, inplace=True)
df_pit.replace(to_replace='.', value='0', inplace=True)
df_pit = df_pit.astype(float, copy=False)

#Merge both DF (PIT and HIC) and drop some unecessary columns
df = pd.concat([df_hic, df_pit], axis=1)
df.drop(index=['Total', ' ', 'MP'], level=1, inplace=True)

#in 2015 there is a KS with an * that we need to fix
df.reset_index(inplace=True)
df = df.replace({'State': {'KS*':'KS'}}).groupby(['year','State'], sort=False).sum()

#Create an aggregate column of the total of all the beds.
df['Total Beds'] = df_hic['Total Year-Round Beds (ES)'] + df_hic['Total Year-Round Beds (TH)'] + df_hic['Total Year-Round Beds (SH)'] + df_hic['Total Year-Round Beds (PSH)'] + df_hic['Total Year-Round Beds (RRH)'] + df_hic['Total Year-Round Beds (DEM)'] + df_hic['Total Year-Round Beds (OPH)']

#Add a column of change to date 
df['Change to date'] = (df['Total Homeless'] - df.loc['2007','Total Homeless']) / (df.loc['2007','Total Homeless'])

#get the length of states and crate an empty list
length = len(df.loc['2007'])
last_year_changes = list()

#pad the list with zeros as 2007 has no population change.
for state in df.loc['2007','Total Homeless']:
    last_year_changes.append(0)

#loop through the years and calculate the population percentage change 
for year in range(2008, 2018):
    listy = pd.Series.tolist((df.loc[str(year), 'Total Homeless'] - df.loc[str(year-1),'Total Homeless']) / (df.loc[str(year-1),'Total Homeless']))
    last_year_changes = last_year_changes + listy

#add the list of changes to the dataframe
df['Change from last year'] = last_year_changes

#add the able column based on the 'Change to date' or 'Change from last year' columns
df['Able'] = (df['Change to date'].map(lambda x: x < 0.00)) & (df['Change from last year'].map(lambda x: x < 0.00))

# %%
#I am checking the head of the df to remind ourselves what it looks like
df.head()
# Out:
#             Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# year State
# 2007 AK                         1095.0                       663.0
#      AL                         1766.0                      2607.0
#      AR                         1483.0                      1109.0
#      AZ                         3736.0                      5597.0
#      CA                        20181.0                     30897.0
#
#             Total Year-Round Beds (SH)  Total Year-Round Beds (PSH)  \
# year State
# 2007 AK                            0.0                        489.0
#      AL                            0.0                       2420.0
#      AR                            0.0                       1538.0
#      AZ                            0.0                       3019.0
#      CA                            0.0                      26787.0
#
#             Total Year-Round Beds (RRH)  Total Year-Round Beds (DEM)  \
# year State
# 2007 AK                             0.0                          0.0
#      AL                             0.0                          0.0
#      AR                             0.0                          0.0
#      AZ                             0.0                          0.0
#      CA                             0.0                          0.0
#
#             Total Year-Round Beds (OPH)  Total Homeless  Number of CoCs  \
# year State
# 2007 AK                             0.0          1642.0             2.0
#      AL                             0.0          5452.0             8.0
#      AR                             0.0          3836.0             9.0
#      AZ                             0.0         14646.0             3.0
#      CA                             0.0        138986.0            42.0
#
#             Total Beds  Change to date  Change from last year   Able
# year State
# 2007 AK         2247.0             0.0                    0.0  False
#      AL         6793.0             0.0                    0.0  False
#      AR         4130.0             0.0                    0.0  False
#      AZ        12352.0             0.0                    0.0  False
#      CA        77865.0             0.0                    0.0  False

# %%
#We describe the df to see basic stats of our dataframe
df.describe()
# Out:
#        Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# count                  594.000000                  594.000000
# mean                  4391.454545                 3378.599327
# std                   8632.767912                 4421.310810
# min                     58.000000                    0.000000
# 25%                   1081.000000                  813.500000
# 50%                   2230.000000                 2158.000000
# 75%                   4247.000000                 3940.250000
# max                  81468.000000                31969.000000
#
#        Total Year-Round Beds (SH)  Total Year-Round Beds (PSH)  \
# count                  594.000000                   594.000000
# mean                    34.442761                  5017.491582
# std                     51.728350                  7912.168142
# min                      0.000000                    22.000000
# 25%                      0.000000                   871.250000
# 50%                     13.000000                  2409.000000
# 75%                     45.000000                  6016.250000
# max                    282.000000                 59836.000000
#
#        Total Year-Round Beds (RRH)  Total Year-Round Beds (DEM)  \
# count                   594.000000                   594.000000
# mean                    478.185185                     8.011785
# std                    1172.229084                    42.520522
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                     339.000000                     0.000000
# max                   11817.000000                   596.000000
#
#        Total Year-Round Beds (OPH)  Total Homeless  Number of CoCs  \
# count                   594.000000      594.000000      594.000000
# mean                    208.828283    11168.698653        7.907407
# std                    1224.239389    19863.448043        8.546856
# min                       0.000000      337.000000        1.000000
# 25%                       0.000000     2247.250000        2.000000
# 50%                       0.000000     5526.000000        4.000000
# 75%                       5.000000    11650.750000       10.000000
# max                   22218.000000   138986.000000       43.000000
#
#           Total Beds  Change to date  Change from last year
# count     594.000000      594.000000             594.000000
# mean    13517.013468        0.021145              -0.004291
# std     19900.731143        0.313976               0.160595
# min       149.000000       -0.680120              -0.504213
# 25%      3091.000000       -0.147263              -0.071907
# 50%      7559.500000        0.000000              -0.004449
# 75%     14648.250000        0.121574               0.036916
# max    135102.000000        2.376164               2.007267

# %%
#We get a correlation matrix to see what columns are correlated with each other.
corr = df.corr()
corr
# Out:
#                              Total Year-Round Beds (ES)  \
# Total Year-Round Beds (ES)                     1.000000
# Total Year-Round Beds (TH)                     0.555505
# Total Year-Round Beds (SH)                     0.548480
# Total Year-Round Beds (PSH)                    0.787216
# Total Year-Round Beds (RRH)                    0.305595
# Total Year-Round Beds (DEM)                    0.051666
# Total Year-Round Beds (OPH)                    0.102184
# Total Homeless                                 0.717937
# Number of CoCs                                 0.624065
# Total Beds                                     0.896013
# Change to date                                -0.008561
# Change from last year                          0.006221
# Able                                          -0.005028
#
#                              Total Year-Round Beds (TH)  \
# Total Year-Round Beds (ES)                     0.555505
# Total Year-Round Beds (TH)                     1.000000
# Total Year-Round Beds (SH)                     0.673917
# Total Year-Round Beds (PSH)                    0.828359
# Total Year-Round Beds (RRH)                    0.258754
# Total Year-Round Beds (DEM)                    0.075555
# Total Year-Round Beds (OPH)                    0.096639
# Total Homeless                                 0.928841
# Number of CoCs                                 0.822896
# Total Beds                                     0.815582
# Change to date                                -0.148737
# Change from last year                         -0.033549
# Able                                           0.092483
#
#                              Total Year-Round Beds (SH)  \
# Total Year-Round Beds (ES)                     0.548480
# Total Year-Round Beds (TH)                     0.673917
# Total Year-Round Beds (SH)                     1.000000
# Total Year-Round Beds (PSH)                    0.670755
# Total Year-Round Beds (RRH)                    0.285120
# Total Year-Round Beds (DEM)                    0.157298
# Total Year-Round Beds (OPH)                    0.152851
# Total Homeless                                 0.635552
# Number of CoCs                                 0.696672
# Total Beds                                     0.683462
# Change to date                                -0.140372
# Change from last year                         -0.033258
# Able                                           0.148787
#
#                              Total Year-Round Beds (PSH)  \
# Total Year-Round Beds (ES)                      0.787216
# Total Year-Round Beds (TH)                      0.828359
# Total Year-Round Beds (SH)                      0.670755
# Total Year-Round Beds (PSH)                     1.000000
# Total Year-Round Beds (RRH)                     0.521336
# Total Year-Round Beds (DEM)                     0.165840
# Total Year-Round Beds (OPH)                     0.205042
# Total Homeless                                  0.901074
# Number of CoCs                                  0.813328
# Total Beds                                      0.968525
# Change to date                                 -0.127647
# Change from last year                          -0.031740
# Able                                            0.088764
#
#                              Total Year-Round Beds (RRH)  \
# Total Year-Round Beds (ES)                      0.305595
# Total Year-Round Beds (TH)                      0.258754
# Total Year-Round Beds (SH)                      0.285120
# Total Year-Round Beds (PSH)                     0.521336
# Total Year-Round Beds (RRH)                     1.000000
# Total Year-Round Beds (DEM)                     0.299435
# Total Year-Round Beds (OPH)                     0.433937
# Total Homeless                                  0.349120
# Number of CoCs                                  0.320849
# Total Beds                                      0.484304
# Change to date                                 -0.148755
# Change from last year                          -0.047497
# Able                                            0.077039
#
#                              Total Year-Round Beds (DEM)  \
# Total Year-Round Beds (ES)                      0.051666
# Total Year-Round Beds (TH)                      0.075555
# Total Year-Round Beds (SH)                      0.157298
# Total Year-Round Beds (PSH)                     0.165840
# Total Year-Round Beds (RRH)                     0.299435
# Total Year-Round Beds (DEM)                     1.000000
# Total Year-Round Beds (OPH)                     0.143747
# Total Homeless                                  0.058154
# Number of CoCs                                  0.098325
# Total Beds                                      0.134160
# Change to date                                 -0.088151
# Change from last year                          -0.057121
# Able                                            0.120674
#
#                              Total Year-Round Beds (OPH)  Total Homeless  \
# Total Year-Round Beds (ES)                      0.102184        0.717937
# Total Year-Round Beds (TH)                      0.096639        0.928841
# Total Year-Round Beds (SH)                      0.152851        0.635552
# Total Year-Round Beds (PSH)                     0.205042        0.901074
# Total Year-Round Beds (RRH)                     0.433937        0.349120
# Total Year-Round Beds (DEM)                     0.143747        0.058154
# Total Year-Round Beds (OPH)                     1.000000        0.116097
# Total Homeless                                  0.116097        1.000000
# Number of CoCs                                  0.196180        0.817202
# Total Beds                                      0.235100        0.905527
# Change to date                                 -0.170064       -0.067724
# Change from last year                          -0.033583        0.001696
# Able                                            0.083968        0.038949
#
#                              Number of CoCs  Total Beds  Change to date  \
# Total Year-Round Beds (ES)         0.624065    0.896013       -0.008561
# Total Year-Round Beds (TH)         0.822896    0.815582       -0.148737
# Total Year-Round Beds (SH)         0.696672    0.683462       -0.140372
# Total Year-Round Beds (PSH)        0.813328    0.968525       -0.127647
# Total Year-Round Beds (RRH)        0.320849    0.484304       -0.148755
# Total Year-Round Beds (DEM)        0.098325    0.134160       -0.088151
# Total Year-Round Beds (OPH)        0.196180    0.235100       -0.170064
# Total Homeless                     0.817202    0.905527       -0.067724
# Number of CoCs                     1.000000    0.809889       -0.209548
# Total Beds                         0.809889    1.000000       -0.107286
# Change to date                    -0.209548   -0.107286        1.000000
# Change from last year             -0.063115   -0.022446        0.497876
# Able                               0.153212    0.064004       -0.514549
#
#                              Change from last year      Able
# Total Year-Round Beds (ES)                0.006221 -0.005028
# Total Year-Round Beds (TH)               -0.033549  0.092483
# Total Year-Round Beds (SH)               -0.033258  0.148787
# Total Year-Round Beds (PSH)              -0.031740  0.088764
# Total Year-Round Beds (RRH)              -0.047497  0.077039
# Total Year-Round Beds (DEM)              -0.057121  0.120674
# Total Year-Round Beds (OPH)              -0.033583  0.083968
# Total Homeless                            0.001696  0.038949
# Number of CoCs                           -0.063115  0.153212
# Total Beds                               -0.022446  0.064004
# Change to date                            0.497876 -0.514549
# Change from last year                     1.000000 -0.403404
# Able                                     -0.403404  1.000000

# %%
#We dispplay the correlatin matrix to have a better visualization of the correlation
size = (20, 10)
sns.set(font_scale=2)
fig, ax = plt.subplots(figsize=size)
sns.heatmap(data=corr,ax=ax, xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True).set_title('Correlation Matrix')
plt.show()

# %% [markdown]
# It looks like Total Homeless and Total Beds has the highest correlation so we will take a closer look at these columns

# %%
#Order the correlations of Total homeless
corr = corr.abs().unstack()
sorted_corr = corr.sort_values(ascending=False)
sorted_corr['Total Homeless']
# Out:
# Total Homeless                 1.000000
# Total Year-Round Beds (TH)     0.928841
# Total Beds                     0.905527
# Total Year-Round Beds (PSH)    0.901074
# Number of CoCs                 0.817202
# Total Year-Round Beds (ES)     0.717937
# Total Year-Round Beds (SH)     0.635552
# Total Year-Round Beds (RRH)    0.349120
# Total Year-Round Beds (OPH)    0.116097
# Change to date                 0.067724
# Total Year-Round Beds (DEM)    0.058154
# Able                           0.038949
# Change from last year          0.001696
# dtype: float64

# %%
#Order the correlations of Total Beds
sorted_corr['Total Beds']
# Out:
# Total Beds                     1.000000
# Total Year-Round Beds (PSH)    0.968525
# Total Homeless                 0.905527
# Total Year-Round Beds (ES)     0.896013
# Total Year-Round Beds (TH)     0.815582
# Number of CoCs                 0.809889
# Total Year-Round Beds (SH)     0.683462
# Total Year-Round Beds (RRH)    0.484304
# Total Year-Round Beds (OPH)    0.235100
# Total Year-Round Beds (DEM)    0.134160
# Change to date                 0.107286
# Able                           0.064004
# Change from last year          0.022446
# dtype: float64

# %%
#We plot the distribution of the homeless
df[['Total Homeless','Total Beds']].plot(kind='hist', figsize=(20,10), bins=30, title='Distribution of the Homeless')
plt.show()

# %%
#We plot the of the homeless vs the beds in a scatter plot
import matplotlib.ticker
fig, ax = plt.subplots(figsize=(20,10))
plt.hist(x=(df['Total Homeless']/df['Total Beds']), bins=30)
plt.title('Total Homeless to Beds Ratio')
plt.xticks(range(5))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(0.25))
plt.show()

# %%
#We plot the of the homeless vs the beds in a scatter plot
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(x=df['Total Homeless'], y=df['Total Beds'])
plt.xlabel('Total Homeless')
plt.ylabel('Total Beds')
plt.title('Total Homeless vs Total Beds')
plt.show()

# %%
#We plot the distribution of CoCs
df['Number of CoCs'].plot(kind='hist', figsize=(20,10), bins=30, title='Distribution of CoCs')
plt.show()

# %% [markdown]
# When viewing the previous scatter and distribnution plots we notice we have some heavy outliers which can skew our data. So we are going to find them which are the outliers and elimnate them are redo the previous plots.

# %%
#we add additional import needed for the following opierations
from scipy import stats
from patsy.builtins import *
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#As we mentioned we need to fin the outliers in our data. I used an influence plot for this.
model = ols("Q('Total Homeless') ~ Q('Total Beds')", df).fit()

fig, ax = plt.subplots(figsize=(20,10))
fig = sm.graphics.influence_plot(model, ax=ax)

# %%
#We can clearly see that NY and CA are the outliers. So we proceed to eliminate them.
df_min = df.drop(index=['CA', 'NY'], level=1)

# %%
#Double check our stats
df_min.describe()
# Out:
#        Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# count                  572.000000                  572.000000
# mean                  3024.409091                 2757.564685
# std                   2806.182804                 2630.894699
# min                     58.000000                    0.000000
# 25%                   1004.750000                  738.500000
# 50%                   1991.000000                 2086.000000
# 75%                   4023.000000                 3633.250000
# max                  13961.000000                14022.000000
#
#        Total Year-Round Beds (SH)  Total Year-Round Beds (PSH)  \
# count                  572.000000                   572.000000
# mean                    29.697552                  3691.722028
# std                     45.086348                  3816.416339
# min                      0.000000                    22.000000
# 25%                      0.000000                   838.000000
# 50%                     12.000000                  2199.500000
# 75%                     42.250000                  5600.250000
# max                    282.000000                 17817.000000
#
#        Total Year-Round Beds (RRH)  Total Year-Round Beds (DEM)  \
# count                   572.000000                   572.000000
# mean                    420.996503                     8.059441
# std                     965.486995                    43.053381
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                     321.250000                     0.000000
# max                    7424.000000                   596.000000
#
#        Total Year-Round Beds (OPH)  Total Homeless  Number of CoCs  \
# count                   572.000000      572.000000      572.000000
# mean                    192.346154     7797.393357        6.832168
# std                    1222.364517     8575.050024        6.555420
# min                       0.000000      337.000000        1.000000
# 25%                       0.000000     2181.250000        2.000000
# 50%                       0.000000     5227.500000        4.000000
# 75%                       0.500000    10520.000000        9.000000
# max                   22218.000000    57551.000000       28.000000
#
#          Total Beds  Change to date  Change from last year
# count    572.000000      572.000000             572.000000
# mean   10124.795455        0.020709              -0.005083
# std     9508.969028        0.317799               0.163244
# min      149.000000       -0.680120              -0.504213
# 25%     2942.250000       -0.149208              -0.074441
# 50%     7053.000000        0.000000              -0.005418
# 75%    13577.500000        0.122161               0.036815
# max    44881.000000        2.376164               2.007267

# %%
#We now create a linear regression plot
sns.set(font_scale=2)
fig, ax = plt.subplots(figsize=size)
sns.regplot(y='Total Homeless', x='Total Beds', data=df_min, fit_reg = True)
plt.title('Linear Regression')
plt.show()
# Out:
# C:\Users\Warvold\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#We double check our distributions
df_min[['Total Homeless','Total Beds']].plot(kind='hist', figsize=(20,10), bins=30, title='Distribution of the Homeless')
plt.show()

# %%
#Double check the CoC distribution
df_min['Number of CoCs'].plot(kind='hist', figsize=(20,10), bins=30, title='Distribution of CoCs')
plt.show()

# %% [markdown]
# ## Final Thoughts

# %% [markdown]
# In this section we want to understnad our data better so we will proceed to do some inferential statistics or better know as exploratory data analysis (EDA). We start off with a refresher of how out data looks like and we proceed to describe it to see some basics stats such as max, min and mean of the columns of our DataFrame. Then we do a correlation matix and plot it. From what we see the most related data is 'Total Homeless' and 'Total Beds' which makes sense. We then plot the distribution of homeless and the beds, the ratio between the beds and the homeless and a scatter plot of the beds and the homeless. When doing the scatter plot we notice that there are some outliers. So we want to take a better look at this using an influence plot. It looks like CA and NY are the culprits.We eliminate our outliers and redo some of our plot and notice a big change in our plots and stats.
#
# Now we have a better understanding of our data. Eliminating the outliers is something to take into cosideration in our next section of Machine Learning, we hope our model peform better without the outliers in our data.
